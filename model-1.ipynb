# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import json
import os
from PIL import Image
import random
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
train_json = '/kaggle/input/tig-aluminium-5083/al5083/train/train.json'

with open(train_json, 'r') as json_file:
    train_data_json = json.load(json_file)

# %%
label_names = ["good weld", "burn through", "contamination", "lack of fusion", "misalignment", "lack of penetration"]
labels = [0, 1, 2, 3, 4, 5]
one_hot_encoding = tf.keras.utils.to_categorical(labels, num_classes=6)
label_count = [0, 0, 0, 0, 0, 0]

# %%
for l in train_data_json:
    label_count[train_data_json[l]] += 1
    
label_count
# Out:
# [8758, 1783, 6325, 4028, 2953, 2819]

# %%
all_data = []
image_size = (256, 256)
label_count = [0, 0, 0, 0, 0, 0]

# %%
def load_data(path):
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if(os.path.isdir(folder_path)):
            for img_name in os.listdir(folder_path):
                
                img_path = os.path.join(folder_path, img_name)
                key_name = folder + '/' + img_name
                label = train_data_json[key_name]
                
                if(label_count[label] > 2000):
                    continue
                    
                label_count[label] += 1
                image = Image.open(img_path).resize(image_size)
                image = tf.convert_to_tensor(image)
                all_data.append((image, one_hot_encoding[label]))
                
                if(len(all_data)%100==0):
                    print(f"Total images loaded : {len(all_data)}, Label count : {label_count}", end = '\r')

# %%
load_data('/kaggle/input/tig-aluminium-5083/al5083/train')
# Out:
# Total images loaded : 11700, Label count : [2001, 1728, 2001, 2001, 1968, 2001]

# %%
random.shuffle(all_data)

# %%
X = []
y = []

for data in all_data:
    X.append(data[0])
    y.append(data[1])

# %%
rand_num = np.random.randint(low = 0, high = len(all_data))
X[rand_num], y[rand_num]
# Out:
# (<tf.Tensor: shape=(256, 256), dtype=uint8, numpy=
#  array([[10, 10, 10, ...,  3,  3,  2],
#         [10, 10, 11, ...,  3,  3,  2],
#         [10, 10, 11, ...,  3,  3,  2],
#         ...,
#         [24, 25, 26, ..., 44, 41, 41],
#         [25, 25, 25, ..., 41, 40, 41],
#         [26, 26, 25, ..., 41, 40, 40]], dtype=uint8)>,
#  array([1., 0., 0., 0., 0., 0.], dtype=float32))

# %%
for _ in range(5):
    rand_img = np.random.randint(low = 0, high = len(X))
    plt.imshow(X[rand_img], cmap='gray')
    plt.show()
    print(f"Label : {label_names[np.argmax(y[rand_img])]}")
# Out:
# Label : good weld
# Label : misalignment
# Label : misalignment
# Label : lack of fusion
# Label : contamination

# %%
total_data = len(X)
X_train, y_train = X[:int(total_data*0.8)], y[:int(total_data*0.8)]
X_test, y_test = X[int(total_data*0.8):], y[int(total_data*0.8):]

# %%
X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
X_test = tf.convert_to_tensor(X_test, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# (TensorShape([9430, 256, 256]),
#  TensorShape([9430, 6]),
#  TensorShape([2358, 256, 256]),
#  TensorShape([2358, 6]))

# %%
X_train = tf.reshape(X_train, shape=(len(X_train), 256, 256, 1))
X_test = tf.reshape(X_test, shape=(len(X_test), 256, 256, 1))

X_train.shape, y_train.shape
# Out:
# (TensorShape([9430, 256, 256, 1]), TensorShape([9430, 6]))

# %%
from tensorflow.keras import layers, regularizers

class MyModel(tf.keras.Model):

    def __init__(self, l2_reg=0.01):
        super().__init__()
        self.conv1 = layers.Conv2D(256, (3, 3), activation='relu', padding='same', input_shape=(image_size[0], image_size[1], 1), kernel_regularizer=regularizers.l2(l2_reg))
        self.pool1 = layers.MaxPooling2D((2, 2))
        self.dropout1 = layers.Dropout(0.2)
        
        self.conv4 = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(l2_reg))
        self.pool4 = layers.MaxPooling2D((2, 2))
        self.dropout3 = layers.Dropout(0.2)
        
        self.conv5 = layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(l2_reg))
        self.pool5 = layers.MaxPooling2D((2, 2))
        
        self.flatten = layers.Flatten()

        self.dense1 = layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))
        self.dense2 = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(l2_reg))
        self.dense3 = layers.Dense(len(labels), activation='softmax')

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.pool1(x)
        x = self.dropout1(x)
        
        x = self.conv4(x)
        x = self.pool4(x)
        x = self.dropout3(x)
        
        x = self.conv5(x)
        x = self.pool5(x)

        x = self.flatten(x)

        x = self.dense1(x)
        x = self.dense2(x)
        output = self.dense3(x)

        return output

# %%
model = MyModel()

model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
print(f"Train dataset Size : {len(X_train)}\nTest Dataset size : {len(X_test)}")
# Out:
# Train dataset Size : 9430
# Test Dataset size : 2358

# %%
callback1 = tf.keras.callbacks.ModelCheckpoint(
    filepath='/model',
    monitor = 'val_accuracy',
    verbose = 1,
    save_best_only = True,
    save_weights_only = True,
)

# %%
model.fit(x=X_train, y=y_train, epochs=25, validation_data=(X_test, y_test), callbacks=[callback1])
# Out:
# Epoch 1/25
# 2024-01-07 11:54:01.057117: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmy_model/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 295/295 [==============================] - ETA: 0s - loss: 10.0289 - accuracy: 0.7946
# Epoch 1: val_accuracy improved from -inf to 0.71204, saving model to /model
# 295/295 [==============================] - 117s 373ms/step - loss: 10.0289 - accuracy: 0.7946 - val_loss: 9.7205 - val_accuracy: 0.7120
# Epoch 2/25
# 295/295 [==============================] - ETA: 0s - loss: 8.8244 - accuracy: 0.9271
# Epoch 2: val_accuracy improved from 0.71204 to 0.83757, saving model to /model
# 295/295 [==============================] - 108s 366ms/step - loss: 8.8244 - accuracy: 0.9271 - val_loss: 8.9305 - val_accuracy: 0.8376
# Epoch 3/25
# 295/295 [==============================] - ETA: 0s - loss: 8.3706 - accuracy: 0.9515
# Epoch 3: val_accuracy improved from 0.83757 to 0.88846, saving model to /model
# 295/295 [==============================] - 108s 368ms/step - loss: 8.3706 - accuracy: 0.9515 - val_loss: 8.3644 - val_accuracy: 0.8885
# Epoch 4/25
# 295/295 [==============================] - ETA: 0s - loss: 7.9575 - accuracy: 0.9702
# Epoch 4: val_accuracy improved from 0.88846 to 0.96565, saving model to /model
# 295/295 [==============================] - 108s 366ms/step - loss: 7.9575 - accuracy: 0.9702 - val_loss: 7.8074 - val_accuracy: 0.9656
# Epoch 5/25
# 295/295 [==============================] - ETA: 0s - loss: 7.6514 - accuracy: 0.9686
# Epoch 5: val_accuracy did not improve from 0.96565
# 295/295 [==============================] - 107s 364ms/step - loss: 7.6514 - accuracy: 0.9686 - val_loss: 7.6175 - val_accuracy: 0.9529
# Epoch 6/25
# 295/295 [==============================] - ETA: 0s - loss: 7.3464 - accuracy: 0.9742
# Epoch 6: val_accuracy did not improve from 0.96565
# 295/295 [==============================] - 107s 364ms/step - loss: 7.3464 - accuracy: 0.9742 - val_loss: 7.3688 - val_accuracy: 0.9042
# Epoch 7/25
# 295/295 [==============================] - ETA: 0s - loss: 7.0586 - accuracy: 0.9786
# Epoch 7: val_accuracy did not improve from 0.96565
# 295/295 [==============================] - 107s 364ms/step - loss: 7.0586 - accuracy: 0.9786 - val_loss: 7.0163 - val_accuracy: 0.9381
# Epoch 8/25
# 295/295 [==============================] - ETA: 0s - loss: 6.7944 - accuracy: 0.9805
# Epoch 8: val_accuracy improved from 0.96565 to 0.98049, saving model to /model
# 295/295 [==============================] - 108s 366ms/step - loss: 6.7944 - accuracy: 0.9805 - val_loss: 6.6589 - val_accuracy: 0.9805
# Epoch 9/25
# 295/295 [==============================] - ETA: 0s - loss: 6.5256 - accuracy: 0.9869
# Epoch 9: val_accuracy did not improve from 0.98049
# 295/295 [==============================] - 107s 364ms/step - loss: 6.5256 - accuracy: 0.9869 - val_loss: 6.4674 - val_accuracy: 0.9584
# Epoch 10/25
# 295/295 [==============================] - ETA: 0s - loss: 6.2902 - accuracy: 0.9866
# Epoch 10: val_accuracy did not improve from 0.98049
# 295/295 [==============================] - 108s 365ms/step - loss: 6.2902 - accuracy: 0.9866 - val_loss: 6.2011 - val_accuracy: 0.9741
# Epoch 11/25
# 295/295 [==============================] - ETA: 0s - loss: 6.0426 - accuracy: 0.9913
# Epoch 11: val_accuracy did not improve from 0.98049
# 295/295 [==============================] - 108s 365ms/step - loss: 6.0426 - accuracy: 0.9913 - val_loss: 5.9552 - val_accuracy: 0.9784
# Epoch 12/25
# 295/295 [==============================] - ETA: 0s - loss: 5.8265 - accuracy: 0.9893
# Epoch 12: val_accuracy did not improve from 0.98049
# 295/295 [==============================] - 108s 365ms/step - loss: 5.8265 - accuracy: 0.9893 - val_loss: 5.8106 - val_accuracy: 0.9453
# Epoch 13/25
# 295/295 [==============================] - ETA: 0s - loss: 5.6026 - accuracy: 0.9903
# Epoch 13: val_accuracy improved from 0.98049 to 0.99406, saving model to /model
# 295/295 [==============================] - 108s 368ms/step - loss: 5.6026 - accuracy: 0.9903 - val_loss: 5.4844 - val_accuracy: 0.9941
# Epoch 14/25
# 295/295 [==============================] - ETA: 0s - loss: 5.3920 - accuracy: 0.9881
# Epoch 14: val_accuracy did not improve from 0.99406
# 295/295 [==============================] - 108s 366ms/step - loss: 5.3920 - accuracy: 0.9881 - val_loss: 5.3432 - val_accuracy: 0.9661
# Epoch 15/25
# 295/295 [==============================] - ETA: 0s - loss: 5.1761 - accuracy: 0.9923
# Epoch 15: val_accuracy did not improve from 0.99406
# 295/295 [==============================] - 108s 367ms/step - loss: 5.1761 - accuracy: 0.9923 - val_loss: 5.0897 - val_accuracy: 0.9890
# Epoch 16/25
# 295/295 [==============================] - ETA: 0s - loss: 4.9854 - accuracy: 0.9878
# Epoch 16: val_accuracy did not improve from 0.99406
# 295/295 [==============================] - 108s 367ms/step - loss: 4.9854 - accuracy: 0.9878 - val_loss: 4.8919 - val_accuracy: 0.9864
# Epoch 17/25
# 295/295 [==============================] - ETA: 0s - loss: 4.7626 - accuracy: 0.9959
# Epoch 17: val_accuracy improved from 0.99406 to 0.99830, saving model to /model
# 295/295 [==============================] - 112s 379ms/step - loss: 4.7626 - accuracy: 0.9959 - val_loss: 4.6681 - val_accuracy: 0.9983
# Epoch 18/25
# 295/295 [==============================] - ETA: 0s - loss: 4.5633 - accuracy: 0.9967
# Epoch 18: val_accuracy did not improve from 0.99830
# 295/295 [==============================] - 109s 368ms/step - loss: 4.5633 - accuracy: 0.9967 - val_loss: 4.5373 - val_accuracy: 0.9665
# Epoch 19/25
# 295/295 [==============================] - ETA: 0s - loss: 4.3841 - accuracy: 0.9918
# Epoch 19: val_accuracy did not improve from 0.99830
# 295/295 [==============================] - 109s 369ms/step - loss: 4.3841 - accuracy: 0.9918 - val_loss: 4.2956 - val_accuracy: 0.9932
# Epoch 20/25
# 295/295 [==============================] - ETA: 0s - loss: 4.2000 - accuracy: 0.9905
# Epoch 20: val_accuracy did not improve from 0.99830
# 295/295 [==============================] - 110s 371ms/step - loss: 4.2000 - accuracy: 0.9905 - val_loss: 4.1344 - val_accuracy: 0.9864
# Epoch 21/25
# 295/295 [==============================] - ETA: 0s - loss: 3.9973 - accuracy: 0.9971
# Epoch 21: val_accuracy did not improve from 0.99830
# 295/295 [==============================] - 110s 373ms/step - loss: 3.9973 - accuracy: 0.9971 - val_loss: 3.9201 - val_accuracy: 0.9966
# Epoch 22/25
# 295/295 [==============================] - ETA: 0s - loss: 3.8262 - accuracy: 0.9935
# Epoch 22: val_accuracy did not improve from 0.99830
# 295/295 [==============================] - 111s 375ms/step - loss: 3.8262 - accuracy: 0.9935 - val_loss: 3.7423 - val_accuracy: 0.9962
# Epoch 23/25
# 295/295 [==============================] - ETA: 0s - loss: 3.6370 - accuracy: 0.9976
# Epoch 23: val_accuracy improved from 0.99830 to 0.99873, saving model to /model
# 295/295 [==============================] - 112s 379ms/step - loss: 3.6370 - accuracy: 0.9976 - val_loss: 3.5553 - val_accuracy: 0.9987
# Epoch 24/25
# 295/295 [==============================] - ETA: 0s - loss: 3.4627 - accuracy: 0.9967
# Epoch 24: val_accuracy did not improve from 0.99873
# 295/295 [==============================] - 111s 378ms/step - loss: 3.4627 - accuracy: 0.9967 - val_loss: 3.5064 - val_accuracy: 0.9398
# Epoch 25/25
# 295/295 [==============================] - ETA: 0s - loss: 3.2952 - accuracy: 0.9948
# Epoch 25: val_accuracy did not improve from 0.99873
# 295/295 [==============================] - 111s 378ms/step - loss: 3.2952 - accuracy: 0.9948 - val_loss: 3.2474 - val_accuracy: 0.9873

# %%
model.load_weights('/model')

# %%
predictions = model.predict(X_test)
# Out:
# 74/74 [==============================] - 3s 35ms/step

# %%
for _ in range(5):
    rand_img = np.random.randint(low = 0, high = len(X_test))
    plt.imshow(X_test[rand_img].numpy(), cmap='gray')
    plt.show()
    print(f"Prediction : {label_names[np.argmax(predictions[rand_img])]}")
    print(f"Original : {label_names[np.argmax(y_test[rand_img])]}")
# Out:
# Prediction : good weld
# Original : good weld
# Prediction : lack of fusion
# Original : lack of fusion
# Prediction : lack of penetration
# Original : lack of penetration
# Prediction : contamination
# Original : contamination
# Prediction : lack of penetration
# Original : lack of penetration

# %%
train_metric = model.evaluate(X_train, y_train, verbose=0)
print(f"Training Loss : {train_metric[0]} , Training Accuracy : {train_metric[1]}")
# Out:
# Training Loss : 3.5529978275299072 , Training Accuracy : 0.998939573764801

# %%
test_metric = model.evaluate(X_test, y_test, verbose=0)
print(f"Testing Loss : {test_metric[0]} , Testing Accuracy : {test_metric[1]}")
# Out:
# Testing Loss : 3.555286407470703 , Testing Accuracy : 0.9987277388572693
